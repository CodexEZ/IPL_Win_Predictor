# %%
import pandas as pd 
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
import pickle
import seaborn as sns

# %%
df = pd.read_csv('dataset.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106604 entries, 0 to 106603
# Data columns (total 10 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   batting_team       106604 non-null  object
#  1   bowling_team       106604 non-null  object
#  2   city               106604 non-null  object
#  3   runs_left          106604 non-null  int64
#  4   balls_left         106604 non-null  int64
#  5   wickets_remaining  106604 non-null  int64
#  6   total_run_x        106604 non-null  int64
#  7   crr                106604 non-null  float64
#  8   rrr                106604 non-null  float64
#  9   results            106604 non-null  int64
# dtypes: float64(2), int64(5), object(3)
# memory usage: 8.1+ MB

# %%
trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse_output=False,drop='first'),['batting_team','bowling_team','city'])
],
remainder='passthrough')

# %%
trf.get_feature_names_out()
# Out:
# array(['trf__batting_team_Delhi Capitals',
#        'trf__batting_team_Gujarat Lions',
#        'trf__batting_team_Gujarat Titans',
#        'trf__batting_team_Kochi Tuskers Kerala',
#        'trf__batting_team_Kolkata Knight Riders',
#        'trf__batting_team_Lucknow Super Giants',
#        'trf__batting_team_Mumbai Indians',
#        'trf__batting_team_Pune Warriors',
#        'trf__batting_team_Punjab Kings',
#        'trf__batting_team_Rajasthan Royals',
#        'trf__batting_team_Rising Pune Supergiant',
#        'trf__batting_team_Rising Pune Supergiants',
#        'trf__batting_team_Royal Challengers Bangalore',
#        'trf__batting_team_Sunrisers Hyderabad',
#        'trf__bowling_team_Delhi Capitals',
#        'trf__bowling_team_Gujarat Lions',
#        'trf__bowling_team_Gujarat Titans',
#        'trf__bowling_team_Kochi Tuskers Kerala',
#        'trf__bowling_team_Kolkata Knight Riders',
#        'trf__bowling_team_Lucknow Super Giants',
#        'trf__bowling_team_Mumbai Indians',
#        'trf__bowling_team_Pune Warriors',
#        'trf__bowling_team_Punjab Kings',
#        'trf__bowling_team_Rajasthan Royals',
#        'trf__bowling_team_Rising Pune Supergiant',
#        'trf__bowling_team_Rising Pune Supergiants',
#        'trf__bowling_team_Royal Challengers Bangalore',
#        'trf__bowling_team_Sunrisers Hyderabad', 'trf__city_Ahmedabad',
#        'trf__city_Bangalore', 'trf__city_Bengaluru',
#        'trf__city_Bloemfontein', 'trf__city_Cape Town',
#        'trf__city_Centurion', 'trf__city_Chandigarh', 'trf__city_Chennai',
#        'trf__city_Cuttack', 'trf__city_Delhi', 'trf__city_Dharamsala',
#        'trf__city_Dubai', 'trf__city_Durban', 'trf__city_East London',
#        'trf__city_Guwahati', 'trf__city_Hyderabad', 'trf__city_Indore',
#        'trf__city_Jaipur', 'trf__city_Johannesburg', 'trf__city_Kanpur',
#        'trf__city_Kimberley', 'trf__city_Kochi', 'trf__city_Kolkata',
#        'trf__city_Lucknow', 'trf__city_Mumbai', 'trf__city_Nagpur',
#        'trf__city_Navi Mumbai', 'trf__city_Port Elizabeth',
#        'trf__city_Pune', 'trf__city_Raipur', 'trf__city_Rajkot',
#        'trf__city_Ranchi', 'trf__city_Sharjah', 'trf__city_Visakhapatnam',
#        'remainder__runs_left', 'remainder__balls_left',
#        'remainder__wickets_remaining', 'remainder__total_run_x',
#        'remainder__crr', 'remainder__rrr', 'remainder__results'],
#       dtype=object)

# %%
df1 = pd.DataFrame(trf.fit_transform(df), columns=trf.get_feature_names_out())
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106604 entries, 0 to 106603
# Data columns (total 69 columns):
#  #   Column                                         Non-Null Count   Dtype
# ---  ------                                         --------------   -----
#  0   trf__batting_team_Delhi Capitals               106604 non-null  float64
#  1   trf__batting_team_Gujarat Lions                106604 non-null  float64
#  2   trf__batting_team_Gujarat Titans               106604 non-null  float64
#  3   trf__batting_team_Kochi Tuskers Kerala         106604 non-null  float64
#  4   trf__batting_team_Kolkata Knight Riders        106604 non-null  float64
#  5   trf__batting_team_Lucknow Super Giants         106604 non-null  float64
#  6   trf__batting_team_Mumbai Indians               106604 non-null  float64
#  7   trf__batting_team_Pune Warriors                106604 non-null  float64
#  8   trf__batting_team_Punjab Kings                 106604 non-null  float64
#  9   trf__batting_team_Rajasthan Royals             106604 non-null  float64
#  10  trf__batting_team_Rising Pune Supergiant       106604 non-null  float64
#  11  trf__batting_team_Rising Pune Supergiants      106604 non-null  float64
#  12  trf__batting_team_Royal Challengers Bangalore  106604 non-null  float64
#  13  trf__batting_team_Sunrisers Hyderabad          106604 non-null  float64
#  14  trf__bowling_team_Delhi Capitals               106604 non-null  float64
#  15  trf__bowling_team_Gujarat Lions                106604 non-null  float64
#  16  trf__bowling_team_Gujarat Titans               106604 non-null  float64
#  17  trf__bowling_team_Kochi Tuskers Kerala         106604 non-null  float64
#  18  trf__bowling_team_Kolkata Knight Riders        106604 non-null  float64
#  19  trf__bowling_team_Lucknow Super Giants         106604 non-null  float64
#  20  trf__bowling_team_Mumbai Indians               106604 non-null  float64
#  21  trf__bowling_team_Pune Warriors                106604 non-null  float64
#  22  trf__bowling_team_Punjab Kings                 106604 non-null  float64
#  23  trf__bowling_team_Rajasthan Royals             106604 non-null  float64
#  24  trf__bowling_team_Rising Pune Supergiant       106604 non-null  float64
#  25  trf__bowling_team_Rising Pune Supergiants      106604 non-null  float64
#  26  trf__bowling_team_Royal Challengers Bangalore  106604 non-null  float64
#  27  trf__bowling_team_Sunrisers Hyderabad          106604 non-null  float64
#  28  trf__city_Ahmedabad                            106604 non-null  float64
#  29  trf__city_Bangalore                            106604 non-null  float64
#  30  trf__city_Bengaluru                            106604 non-null  float64
#  31  trf__city_Bloemfontein                         106604 non-null  float64
#  32  trf__city_Cape Town                            106604 non-null  float64
#  33  trf__city_Centurion                            106604 non-null  float64
#  34  trf__city_Chandigarh                           106604 non-null  float64
#  35  trf__city_Chennai                              106604 non-null  float64
#  36  trf__city_Cuttack                              106604 non-null  float64
#  37  trf__city_Delhi                                106604 non-null  float64
#  38  trf__city_Dharamsala                           106604 non-null  float64
#  39  trf__city_Dubai                                106604 non-null  float64
#  40  trf__city_Durban                               106604 non-null  float64
#  41  trf__city_East London                          106604 non-null  float64
#  42  trf__city_Guwahati                             106604 non-null  float64
#  43  trf__city_Hyderabad                            106604 non-null  float64
#  44  trf__city_Indore                               106604 non-null  float64
#  45  trf__city_Jaipur                               106604 non-null  float64
#  46  trf__city_Johannesburg                         106604 non-null  float64
#  47  trf__city_Kanpur                               106604 non-null  float64
#  48  trf__city_Kimberley                            106604 non-null  float64
#  49  trf__city_Kochi                                106604 non-null  float64
#  50  trf__city_Kolkata                              106604 non-null  float64
#  51  trf__city_Lucknow                              106604 non-null  float64
#  52  trf__city_Mumbai                               106604 non-null  float64
#  53  trf__city_Nagpur                               106604 non-null  float64
#  54  trf__city_Navi Mumbai                          106604 non-null  float64
#  55  trf__city_Port Elizabeth                       106604 non-null  float64
#  56  trf__city_Pune                                 106604 non-null  float64
#  57  trf__city_Raipur                               106604 non-null  float64
#  58  trf__city_Rajkot                               106604 non-null  float64
#  59  trf__city_Ranchi                               106604 non-null  float64
#  60  trf__city_Sharjah                              106604 non-null  float64
#  61  trf__city_Visakhapatnam                        106604 non-null  float64
#  62  remainder__runs_left                           106604 non-null  float64
#  63  remainder__balls_left                          106604 non-null  float64
#  64  remainder__wickets_remaining                   106604 non-null  float64
#  65  remainder__total_run_x                         106604 non-null  float64
#  66  remainder__crr                                 106604 non-null  float64
#  67  remainder__rrr                                 106604 non-null  float64
#  68  remainder__results                             106604 non-null  float64
# dtypes: float64(69)
# memory usage: 56.1 MB

# %%
ra_pipe = Pipeline([
    ('step1',trf),
    ('step2',RandomForestClassifier())
])

# %%
x = df.iloc[:, :-1]
y = df.iloc[:,-1]
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=100)

# %%
ra_pipe.fit(x_train,y_train)
# Out:
# C:\Users\prata\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\compose\_column_transformer.py:1667: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', RandomForestClassifier())])

# %%
ra_y_pred = ra_pipe.predict(x_test)

# %%
print(accuracy_score(y_test,ra_y_pred)*100 ,"% accuracy")
# Out:
# 99.90244268507749 % accuracy

# %%
x_train[x_train['batting_team'] == 'Chennai Super Kings'].iloc[10]
# Out:
# batting_team         Chennai Super Kings
# bowling_team                Punjab Kings
# city                             Chennai
# runs_left                             92
# balls_left                            74
# wickets_remaining                      8
# total_run_x                          157
# crr                                 8.48
# rrr                                 7.46
# Name: 67592, dtype: object

# %%
data = pd.DataFrame({
    'batting_team':['Chennai Super Kings'],
    'bowling_team':['Punjab Kings'],
    'city':['Chennai'],
    'runs_left':[92],
    'balls_left':[74],
    'wickets_remaining':[8],
    'total_run_x':[157],
    'crr':[8.48],
    'rrr':[7.46]
})

# %%
ra_pipe.predict_proba(data)
# Out:
# array([[0.97, 0.03]])

# %%
65/7
# Out:
# 9.285714285714286

# %%
pickle.dump(ra_pipe,open('model.pkl','wb'))
